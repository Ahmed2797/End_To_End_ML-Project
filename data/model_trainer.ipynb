# %%
import numpy as np 
import pandas as pd
from sklearn.preprocessing import StandardScaler,OneHotEncoder,LabelEncoder,OrdinalEncoder
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer

def labelencoder(df,Columns):
    #df = pd.read_csv("artifacts/data.csv")

    for col in Columns:
        le = LabelEncoder()
        df[col] = le.fit_transform(df[col].astype(str))

    return df

# %%
df = pd.read_csv(r"C:\Users\tanvi\Downloads\Machine Learning\Dataset\airlines_flights_data.csv")

# %%
df.head()
# Out:
#    index   airline   flight source_city departure_time stops   arrival_time  \
# 0      0  SpiceJet  SG-8709       Delhi        Evening  zero          Night
# 1      1  SpiceJet  SG-8157       Delhi  Early_Morning  zero        Morning
# 2      2   AirAsia   I5-764       Delhi  Early_Morning  zero  Early_Morning
# 3      3   Vistara   UK-995       Delhi        Morning  zero      Afternoon
# 4      4   Vistara   UK-963       Delhi        Morning  zero        Morning
#
#   destination_city    class  duration  days_left  price
# 0           Mumbai  Economy      2.17          1   5953
# 1           Mumbai  Economy      2.33          1   5953
# 2           Mumbai  Economy      2.17          1   5956
# 3           Mumbai  Economy      2.25          1   5955
# 4           Mumbai  Economy      2.33          1   5955

# %% [markdown]
# # Data_clean & Save

# %%
df.flight.value_counts()
# Out:
# flight
# UK-706     3235
# UK-772     2741
# UK-720     2650
# UK-836     2542
# UK-822     2468
#            ...
# SG-9923       1
# 6E-6474       1
# 6E-865        1
# G8-705        1
# G8-107        1
# Name: count, Length: 1561, dtype: int64

# %%
df['flight'] = df.flight.str.split('-').str[0]
df.flight = df.flight.replace({'6.00E':'6E','0.00E+00':'6E'})

# %%
df.flight.value_counts()
# Out:
# flight
# UK    127859
# AI     80892
# 6E     43120
# G8     23173
# I5     16098
# SG      9011
# Name: count, dtype: int64

# %%
df.head()
# Out:
#    index   airline flight source_city departure_time stops   arrival_time  \
# 0      0  SpiceJet     SG       Delhi        Evening  zero          Night
# 1      1  SpiceJet     SG       Delhi  Early_Morning  zero        Morning
# 2      2   AirAsia     I5       Delhi  Early_Morning  zero  Early_Morning
# 3      3   Vistara     UK       Delhi        Morning  zero      Afternoon
# 4      4   Vistara     UK       Delhi        Morning  zero        Morning
#
#   destination_city    class  duration  days_left  price
# 0           Mumbai  Economy      2.17          1   5953
# 1           Mumbai  Economy      2.33          1   5953
# 2           Mumbai  Economy      2.17          1   5956
# 3           Mumbai  Economy      2.25          1   5955
# 4           Mumbai  Economy      2.33          1   5955

# %%
df['departure_time'] = np.where(df['departure_time'] == 'Early_Morning', 'Morning',
                              np.where(df['departure_time'] == 'Afternoon', 'Evening',
                              np.where(df['departure_time'] == 'Late_Night', 'Night',
                                       df['departure_time'])))

df['arrival_time'] = df['arrival_time'].replace({
    'Early_Morning':'Morning',
    'Afternoon':'Evening',
    'Late_Night':'Night'
})

df['duration_hours'] = df['duration'].astype(int)
df['duration_minutes'] = ((df['duration'] - df['duration_hours']) * 60).round().astype(int)

df.drop(['duration','index'],axis=1,inplace=True)

# %%
df.head()
# Out:
#     airline flight source_city departure_time stops arrival_time  \
# 0  SpiceJet     SG       Delhi        Evening  zero        Night
# 1  SpiceJet     SG       Delhi        Morning  zero      Morning
# 2   AirAsia     I5       Delhi        Morning  zero      Morning
# 3   Vistara     UK       Delhi        Morning  zero      Evening
# 4   Vistara     UK       Delhi        Morning  zero      Morning
#
#   destination_city    class  days_left  price  duration_hours  \
# 0           Mumbai  Economy          1   5953               2
# 1           Mumbai  Economy          1   5953               2
# 2           Mumbai  Economy          1   5956               2
# 3           Mumbai  Economy          1   5955               2
# 4           Mumbai  Economy          1   5955               2
#
#    duration_minutes
# 0                10
# 1                20
# 2                10
# 3                15
# 4                20

# %%
df.to_csv("Flight_clean.csv", index=False)

# %%
df.head()
# Out:
#     airline flight source_city departure_time stops arrival_time  \
# 0  SpiceJet     SG       Delhi        Evening  zero        Night
# 1  SpiceJet     SG       Delhi        Morning  zero      Morning
# 2   AirAsia     I5       Delhi        Morning  zero      Morning
# 3   Vistara     UK       Delhi        Morning  zero      Evening
# 4   Vistara     UK       Delhi        Morning  zero      Morning
#
#   destination_city    class  days_left  price  duration_hours  \
# 0           Mumbai  Economy          1   5953               2
# 1           Mumbai  Economy          1   5953               2
# 2           Mumbai  Economy          1   5956               2
# 3           Mumbai  Economy          1   5955               2
# 4           Mumbai  Economy          1   5955               2
#
#    duration_minutes
# 0                10
# 1                20
# 2                10
# 3                15
# 4                20

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300153 entries, 0 to 300152
# Data columns (total 12 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   airline           300153 non-null  object
#  1   flight            300153 non-null  object
#  2   source_city       300153 non-null  object
#  3   departure_time    300153 non-null  object
#  4   stops             300153 non-null  object
#  5   arrival_time      300153 non-null  object
#  6   destination_city  300153 non-null  object
#  7   class             300153 non-null  object
#  8   days_left         300153 non-null  int64
#  9   price             300153 non-null  int64
#  10  duration_hours    300153 non-null  int64
#  11  duration_minutes  300153 non-null  int64
# dtypes: int64(4), object(8)
# memory usage: 27.5+ MB

# %%
df.to_csv("Flight_clean.csv", index=False)

# %% [markdown]
# ## All Categorical_Columns LabelEnoden

# %%
#label = ['airline','flight','source_city','departure_time','stops','arrival_time','destination_city','class']
label = df.select_dtypes(include='object')


data = labelencoder(df,label)
data
# Out:
#         airline  flight  source_city  departure_time  stops  arrival_time  \
# index
# 0             4       4            2               2      2             5
# 1             4       4            2               1      2             4
# 2             0       3            2               1      2             1
# 3             5       5            2               4      2             0
# 4             5       5            2               4      2             4
# ...         ...     ...          ...             ...    ...           ...
# 300148        5       5            1               4      0             2
# 300149        5       5            1               0      0             5
# 300150        5       5            1               1      0             5
# 300151        5       5            1               1      0             2
# 300152        5       5            1               4      0             2
#
#         destination_city  class  duration  days_left  price
# index
# ...

# %%
x = data.drop('price',axis=1)
y = data.price

# %%
from sklearn.model_selection import train_test_split
xtrain,xtest,ytrain,ytest = train_test_split(x,y,test_size=0.2,random_state=42)
print(xtrain.shape)
print(xtest.shape)
print(ytrain.shape)
# Out:
# (240122, 10)
# (60031, 10)
# (240122,)

# %%
from sklearn.ensemble import RandomForestRegressor
rf = RandomForestRegressor()
rf.fit(xtrain,ytrain)
print(rf.score(xtest,ytest))
# Out:
# 0.9849403237662718
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[59], line 8
#       6 print(rf.score(xtest,ytest))
#       7 end = time.time()
# ----> 8 print(total = end - start)
#
# TypeError: print() got an unexpected keyword argument 'total'

# %% [markdown]
# ## Select Importance Features

# %%
from sklearn.feature_selection import SelectFromModel

rf = RandomForestRegressor(n_estimators=100, random_state=42)
rf.fit(x, y)

selector = SelectFromModel(rf, threshold=0.01, prefit=True)
X_selected = selector.transform(x)


selected_features = x.columns[selector.get_support()]
print("Selected Features:", selected_features)

importances = rf.feature_importances_
feature_names = x.columns

feat_importances = pd.Series(importances, index=feature_names)
feat_importances = feat_importances.sort_values(ascending=False)
print(feat_importances)
# Out:
# c:\Users\tanvi\miniconda3\envs\env\Lib\site-packages\sklearn\utils\validation.py:2742: UserWarning: X has feature names, but SelectFromModel was fitted without feature names
#   warnings.warn(
# Selected Features: Index(['source_city', 'class', 'duration', 'days_left'], dtype='object')
# class               0.880106
# duration            0.059514
# days_left           0.018657
# source_city         0.010748
# destination_city    0.009534
# flight              0.005539
# airline             0.005263
# arrival_time        0.004557
# departure_time      0.004229
# stops               0.001853
# dtype: float64

# %%
X_selected
# Out:
# array([[ 2.  ,  1.  ,  2.17,  1.  ],
#        [ 2.  ,  1.  ,  2.33,  1.  ],
#        [ 2.  ,  1.  ,  2.17,  1.  ],
#        ...,
#        [ 1.  ,  0.  , 13.83, 49.  ],
#        [ 1.  ,  0.  , 10.  , 49.  ],
#        [ 1.  ,  0.  , 10.08, 49.  ]], shape=(300153, 4))

# %%
x_train,xtest,ytrain,ytest = train_test_split(X_selected,y,test_size=0.2,random_state=42)
rf.fit(x_train,ytrain)
print(rf.score(xtest,ytest))
# Out:
# 0.9336330447835891

# %%
# --------------------------new_x---------------------

# %%
new_x = x[['source_city', 'class', 'duration', 'days_left','destination_city','flight','airline']]

# %%
new_x
# Out:
#         source_city  class  duration  days_left  destination_city  flight  \
# index
# 0                 2      1      2.17          1                 5       4
# 1                 2      1      2.33          1                 5       4
# 2                 2      1      2.17          1                 5       3
# 3                 2      1      2.25          1                 5       5
# 4                 2      1      2.33          1                 5       5
# ...             ...    ...       ...        ...               ...     ...
# 300148            1      0     10.08         49                 3       5
# 300149            1      0     10.42         49                 3       5
# 300150            1      0     13.83         49                 3       5
# 300151            1      0     10.00         49                 3       5
# 300152            1      0     10.08         49                 3       5
#
#         airline
# index
# 0             4
# 1             4
# ...

# %%
y
# Out:
# index
# 0          5953
# 1          5953
# 2          5956
# 3          5955
# 4          5955
#           ...
# 300148    69265
# 300149    77105
# 300150    79099
# 300151    81585
# 300152    81585
# Name: price, Length: 300153, dtype: int64

# %%
x_train,xtest,ytrain,ytest = train_test_split(new_x,y,test_size=0.2,random_state=42)
rf.fit(x_train,ytrain)
print(rf.score(xtest,ytest))
# Out:
# 0.9784275720695403

# %% [markdown]
# # Data_Transformation

# %%
numerical_cols = ['duration','days_left']
ohe_cols = ['airline','flight','source_city','destination_city','departure_time','arrival_time']
label_encode_cols = ['stops','class']


ohe_pipeline = Pipeline(steps=[
    ('ohe',OneHotEncoder(handle_unknown='ignore', sparse_output=False))

])


preprocessor = ColumnTransformer(transformers=[
    ('ohe_pipeline', ohe_pipeline, ohe_cols),
    ('scaler', StandardScaler(), numerical_cols)
], remainder='passthrough')

df_preprocessed = preprocessor.fit_transform(df)
